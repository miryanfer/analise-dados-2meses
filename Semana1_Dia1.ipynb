# %% [markdown]
# <a href="https://colab.research.google.com/github/miryanfer/analise-dados-2meses/blob/main/Semana1_Dia1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, Analista de Dados! 🚀")
nome = input("Qual seu nome? ")
print(f"Seja bem-vinda ao início da sua jornada, {nome}!")
# Out:
# Olá, Analista de Dados! 🚀
# Qual seu nome? mirian
# Seja bem-vinda ao início da sua jornada, mirian!
